# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL #pillow to handle images
import tensorflow as tf

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz" #tgz = tar ball (just like zip file)
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 [==============================] - 12s 0us/step

# %%
valid_size = .2

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torchvision
from torchvision import datasets, transforms, models
from torch.utils.data.sampler import SubsetRandomSampler
import time

# %%
# Normalize the test and train sets with torchvision
train_transforms = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(30),
    transforms.Normalize(
    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

valid_transforms = transforms.Compose([transforms.Resize((224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize(
                                       mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                          ])

# %%
NUM_EPOCHS = 10
lr = 0.001
batch_size = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
DEVICE
# Out:
# device(type='cuda')

# %%
# ImageFolder class to load the train and test images
train_data = datasets.ImageFolder(data_dir, transform=train_transforms)
valid_data = datasets.ImageFolder(data_dir, transform=valid_transforms)

# %%
# Number of train images
num_train = len(train_data)
indices = list(range(num_train))

# %%
# Split = 20% of train images
split = int(np.floor(valid_size * num_train))
# Shuffle indices of train images
np.random.shuffle(indices)

# %%
# Subset indices for test and train
train_idx, valid_idx = indices[split:], indices[:split]

# %%
# Samples elements randomly from a given list of indices
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
# Batch and load the images
train_loader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(valid_data, sampler=valid_sampler, batch_size=batch_size)

# %%
examples = iter(train_loader)
samples ,labels = next(examples)
samples.shape
# Out:
# torch.Size([32, 3, 224, 224])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
for i in range(4):
    plt.subplot(2,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(samples[i][0])
plt.show()

# %%
def imshow(img,title):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(25,20))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title(title)
    plt.show()

# %%
sample = samples[:4]
label = labels[:4]
out = torchvision.utils.make_grid(sample)

# %%
class_name = train_data.classes

# %%
imshow(out,title=[class_name[x] for x in label])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def imshow(img):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(8,8))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    #plt.title(title)
    plt.show()
imshow(samples[0])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = nn.Sequential(nn.Conv2d(3,32,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.Conv2d(32,64,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.MaxPool2d(2,2),
                     nn.Conv2d(64,128,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.Conv2d(128,128,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.MaxPool2d(2,2),
                     nn.Conv2d(128,256,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.Conv2d(256,256,kernel_size=3,stride=1,padding=1),
                     nn.ReLU(),
                     nn.MaxPool2d(2,2),
                     nn.Flatten(),
                     nn.Linear(256*28*28,512),
                     nn.ReLU(),
                     nn.Linear(512,256),
                     nn.ReLU(),
                     nn.Linear(256,5))

# %%
model = model.to(DEVICE)

# %%
#criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

# %%
def compute_accuracy(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100


start_time = time.time()
for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        probas = model(features)
        cost = F.cross_entropy(probas, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 4:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

    # no need to build the computation graph for backprop when computing accuracy
    with torch.set_grad_enabled(False):
        train_acc = compute_accuracy(model, train_loader, device=DEVICE)
        valid_acc = compute_accuracy(model, valid_loader, device=DEVICE)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Validation Acc.: {valid_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
  
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/010 | Batch 000/092 | Cost: 1.6065
# Epoch: 001/010 | Batch 004/092 | Cost: 1.6433
# Epoch: 001/010 | Batch 008/092 | Cost: 1.5147
# Epoch: 001/010 | Batch 012/092 | Cost: 1.5942
# Epoch: 001/010 | Batch 016/092 | Cost: 1.6070
# Epoch: 001/010 | Batch 020/092 | Cost: 1.6047
# Epoch: 001/010 | Batch 024/092 | Cost: 1.5551
# Epoch: 001/010 | Batch 028/092 | Cost: 1.4724
# Epoch: 001/010 | Batch 032/092 | Cost: 1.4290
# Epoch: 001/010 | Batch 036/092 | Cost: 1.4587
# Epoch: 001/010 | Batch 040/092 | Cost: 1.3568
# Epoch: 001/010 | Batch 044/092 | Cost: 1.2917
# Epoch: 001/010 | Batch 048/092 | Cost: 1.2946
# Epoch: 001/010 | Batch 052/092 | Cost: 1.2788
# Epoch: 001/010 | Batch 056/092 | Cost: 1.3600
# Epoch: 001/010 | Batch 060/092 | Cost: 1.2182
# Epoch: 001/010 | Batch 064/092 | Cost: 1.5341
# Epoch: 001/010 | Batch 068/092 | Cost: 1.3977
# Epoch: 001/010 | Batch 072/092 | Cost: 1.3677
# Epoch: 001/010 | Batch 076/092 | Cost: 1.3860
# Epoch: 001/010 | Batch 080/092 | Cost: 1.5184
# Epoch: 001/010 | Batch 084/092 | Cost: 1.2927
# Epoch: 001/010 | Batch 088/092 | Cost: 1.3717
# Epoch: 001/010 Train Acc.: 38.32% | Validation Acc.: 39.92%
# Time elapsed: 1.08 min
# Epoch: 002/010 | Batch 000/092 | Cost: 1.1834
# Epoch: 002/010 | Batch 004/092 | Cost: 1.3236
# Epoch: 002/010 | Batch 008/092 | Cost: 1.2953
# Epoch: 002/010 | Batch 012/092 | Cost: 1.4918
# Epoch: 002/010 | Batch 016/092 | Cost: 1.3173
# Epoch: 002/010 | Batch 020/092 | Cost: 1.1951
# Epoch: 002/010 | Batch 024/092 | Cost: 1.2798
# Epoch: 002/010 | Batch 028/092 | Cost: 1.2893
# Epoch: 002/010 | Batch 032/092 | Cost: 1.2401
# Epoch: 002/010 | Batch 036/092 | Cost: 1.3562
# Epoch: 002/010 | Batch 040/092 | Cost: 1.2933
# Epoch: 002/010 | Batch 044/092 | Cost: 0.9746
# Epoch: 002/010 | Batch 048/092 | Cost: 0.9317
# Epoch: 002/010 | Batch 052/092 | Cost: 1.3814
# Epoch: 002/010 | Batch 056/092 | Cost: 1.1152
# Epoch: 002/010 | Batch 060/092 | Cost: 1.2973
# Epoch: 002/010 | Batch 064/092 | Cost: 1.1327
# Epoch: 002/010 | Batch 068/092 | Cost: 1.1304
# Epoch: 002/010 | Batch 072/092 | Cost: 1.1500
# Epoch: 002/010 | Batch 076/092 | Cost: 1.1629
# Epoch: 002/010 | Batch 080/092 | Cost: 1.2340
# Epoch: 002/010 | Batch 084/092 | Cost: 1.1599
# Epoch: 002/010 | Batch 088/092 | Cost: 1.2107
# Epoch: 002/010 Train Acc.: 48.33% | Validation Acc.: 47.28%
# Time elapsed: 2.07 min
# Epoch: 003/010 | Batch 000/092 | Cost: 1.0915
# Epoch: 003/010 | Batch 004/092 | Cost: 1.4848
# Epoch: 003/010 | Batch 008/092 | Cost: 1.4344
# Epoch: 003/010 | Batch 012/092 | Cost: 1.0610
# Epoch: 003/010 | Batch 016/092 | Cost: 1.1389
# Epoch: 003/010 | Batch 020/092 | Cost: 1.2642
# Epoch: 003/010 | Batch 024/092 | Cost: 1.2230
# Epoch: 003/010 | Batch 028/092 | Cost: 1.1155
# Epoch: 003/010 | Batch 032/092 | Cost: 1.0702
# Epoch: 003/010 | Batch 036/092 | Cost: 1.0681
# Epoch: 003/010 | Batch 040/092 | Cost: 1.2304
# Epoch: 003/010 | Batch 044/092 | Cost: 1.1525
# Epoch: 003/010 | Batch 048/092 | Cost: 1.2327
# Epoch: 003/010 | Batch 052/092 | Cost: 1.1743
# Epoch: 003/010 | Batch 056/092 | Cost: 1.2486
# Epoch: 003/010 | Batch 060/092 | Cost: 1.0972
# Epoch: 003/010 | Batch 064/092 | Cost: 1.0443
# Epoch: 003/010 | Batch 068/092 | Cost: 1.1464
# Epoch: 003/010 | Batch 072/092 | Cost: 1.0789
# Epoch: 003/010 | Batch 076/092 | Cost: 1.0703
# Epoch: 003/010 | Batch 080/092 | Cost: 1.3116
# Epoch: 003/010 | Batch 084/092 | Cost: 1.3093
# Epoch: 003/010 | Batch 088/092 | Cost: 0.8601
# Epoch: 003/010 Train Acc.: 50.82% | Validation Acc.: 51.23%
# Time elapsed: 3.05 min
# Epoch: 004/010 | Batch 000/092 | Cost: 1.1586
# Epoch: 004/010 | Batch 004/092 | Cost: 1.1100
# Epoch: 004/010 | Batch 008/092 | Cost: 0.8836
# Epoch: 004/010 | Batch 012/092 | Cost: 1.0561
# Epoch: 004/010 | Batch 016/092 | Cost: 1.0545
# Epoch: 004/010 | Batch 020/092 | Cost: 1.1491
# Epoch: 004/010 | Batch 024/092 | Cost: 1.2910
# Epoch: 004/010 | Batch 028/092 | Cost: 1.0335
# Epoch: 004/010 | Batch 032/092 | Cost: 1.3571
# Epoch: 004/010 | Batch 036/092 | Cost: 1.1926
# Epoch: 004/010 | Batch 040/092 | Cost: 1.2660
# Epoch: 004/010 | Batch 044/092 | Cost: 1.5088
# Epoch: 004/010 | Batch 048/092 | Cost: 1.2129
# Epoch: 004/010 | Batch 052/092 | Cost: 1.3865
# Epoch: 004/010 | Batch 056/092 | Cost: 1.0053
# Epoch: 004/010 | Batch 060/092 | Cost: 0.9017
# Epoch: 004/010 | Batch 064/092 | Cost: 0.9602
# Epoch: 004/010 | Batch 068/092 | Cost: 1.1151
# Epoch: 004/010 | Batch 072/092 | Cost: 1.1703
# Epoch: 004/010 | Batch 076/092 | Cost: 0.9892
# Epoch: 004/010 | Batch 080/092 | Cost: 1.1231
# Epoch: 004/010 | Batch 084/092 | Cost: 1.1371
# Epoch: 004/010 | Batch 088/092 | Cost: 1.2978
# Epoch: 004/010 Train Acc.: 52.28% | Validation Acc.: 52.72%
# Time elapsed: 4.02 min
# Epoch: 005/010 | Batch 000/092 | Cost: 1.2864
# Epoch: 005/010 | Batch 004/092 | Cost: 1.0863
# Epoch: 005/010 | Batch 008/092 | Cost: 1.1638
# Epoch: 005/010 | Batch 012/092 | Cost: 0.9997
# Epoch: 005/010 | Batch 016/092 | Cost: 0.9783
# Epoch: 005/010 | Batch 020/092 | Cost: 1.2790
# Epoch: 005/010 | Batch 024/092 | Cost: 0.8843
# Epoch: 005/010 | Batch 028/092 | Cost: 0.6928
# Epoch: 005/010 | Batch 032/092 | Cost: 0.7998
# Epoch: 005/010 | Batch 036/092 | Cost: 1.5194
# Epoch: 005/010 | Batch 040/092 | Cost: 0.8702
# Epoch: 005/010 | Batch 044/092 | Cost: 0.8032
# Epoch: 005/010 | Batch 048/092 | Cost: 0.9918
# Epoch: 005/010 | Batch 052/092 | Cost: 0.8344
# Epoch: 005/010 | Batch 056/092 | Cost: 1.2473
# Epoch: 005/010 | Batch 060/092 | Cost: 1.0894
# Epoch: 005/010 | Batch 064/092 | Cost: 0.7433
# Epoch: 005/010 | Batch 068/092 | Cost: 1.3455
# Epoch: 005/010 | Batch 072/092 | Cost: 1.2412
# Epoch: 005/010 | Batch 076/092 | Cost: 1.0612
# Epoch: 005/010 | Batch 080/092 | Cost: 1.2879
# Epoch: 005/010 | Batch 084/092 | Cost: 0.8383
# Epoch: 005/010 | Batch 088/092 | Cost: 1.0556
# Epoch: 005/010 Train Acc.: 64.48% | Validation Acc.: 61.04%
# Time elapsed: 5.00 min
# Epoch: 006/010 | Batch 000/092 | Cost: 1.0060
# Epoch: 006/010 | Batch 004/092 | Cost: 0.8330
# Epoch: 006/010 | Batch 008/092 | Cost: 1.1874
# Epoch: 006/010 | Batch 012/092 | Cost: 0.9652
# Epoch: 006/010 | Batch 016/092 | Cost: 1.0167
# Epoch: 006/010 | Batch 020/092 | Cost: 1.0208
# Epoch: 006/010 | Batch 024/092 | Cost: 0.7663
# Epoch: 006/010 | Batch 028/092 | Cost: 0.5649
# Epoch: 006/010 | Batch 032/092 | Cost: 0.7705
# Epoch: 006/010 | Batch 036/092 | Cost: 1.1391
# Epoch: 006/010 | Batch 040/092 | Cost: 0.7410
# Epoch: 006/010 | Batch 044/092 | Cost: 0.7827
# Epoch: 006/010 | Batch 048/092 | Cost: 0.9567
# Epoch: 006/010 | Batch 052/092 | Cost: 1.0579
# Epoch: 006/010 | Batch 056/092 | Cost: 0.7117
# Epoch: 006/010 | Batch 060/092 | Cost: 1.0643
# Epoch: 006/010 | Batch 064/092 | Cost: 0.9701
# Epoch: 006/010 | Batch 068/092 | Cost: 0.6797
# Epoch: 006/010 | Batch 072/092 | Cost: 0.7956
# Epoch: 006/010 | Batch 076/092 | Cost: 1.0253
# Epoch: 006/010 | Batch 080/092 | Cost: 0.9187
# Epoch: 006/010 | Batch 084/092 | Cost: 0.8501
# Epoch: 006/010 | Batch 088/092 | Cost: 0.6563
# Epoch: 006/010 Train Acc.: 66.76% | Validation Acc.: 62.53%
# Time elapsed: 5.98 min
# Epoch: 007/010 | Batch 000/092 | Cost: 0.6147
# Epoch: 007/010 | Batch 004/092 | Cost: 0.7969
# Epoch: 007/010 | Batch 008/092 | Cost: 0.7852
# Epoch: 007/010 | Batch 012/092 | Cost: 0.6449
# Epoch: 007/010 | Batch 016/092 | Cost: 1.0036
# Epoch: 007/010 | Batch 020/092 | Cost: 0.6900
# Epoch: 007/010 | Batch 024/092 | Cost: 0.9670
# Epoch: 007/010 | Batch 028/092 | Cost: 0.6055
# Epoch: 007/010 | Batch 032/092 | Cost: 0.7462
# Epoch: 007/010 | Batch 036/092 | Cost: 1.1426
# Epoch: 007/010 | Batch 040/092 | Cost: 0.9012
# Epoch: 007/010 | Batch 044/092 | Cost: 0.8085
# Epoch: 007/010 | Batch 048/092 | Cost: 0.7735
# Epoch: 007/010 | Batch 052/092 | Cost: 0.8831
# Epoch: 007/010 | Batch 056/092 | Cost: 1.1477
# Epoch: 007/010 | Batch 060/092 | Cost: 0.7875
# Epoch: 007/010 | Batch 064/092 | Cost: 0.8353
# Epoch: 007/010 | Batch 068/092 | Cost: 0.9409
# Epoch: 007/010 | Batch 072/092 | Cost: 0.6633
# Epoch: 007/010 | Batch 076/092 | Cost: 0.7469
# Epoch: 007/010 | Batch 080/092 | Cost: 0.7566
# Epoch: 007/010 | Batch 084/092 | Cost: 0.7302
# Epoch: 007/010 | Batch 088/092 | Cost: 1.5163
# Epoch: 007/010 Train Acc.: 66.49% | Validation Acc.: 61.72%
# Time elapsed: 6.96 min
# Epoch: 008/010 | Batch 000/092 | Cost: 0.8577
# Epoch: 008/010 | Batch 004/092 | Cost: 0.8202
# Epoch: 008/010 | Batch 008/092 | Cost: 0.7897
# Epoch: 008/010 | Batch 012/092 | Cost: 1.1631
# Epoch: 008/010 | Batch 016/092 | Cost: 0.8028
# Epoch: 008/010 | Batch 020/092 | Cost: 0.8181
# Epoch: 008/010 | Batch 024/092 | Cost: 0.5081
# Epoch: 008/010 | Batch 028/092 | Cost: 0.7183
# Epoch: 008/010 | Batch 032/092 | Cost: 0.8869
# Epoch: 008/010 | Batch 036/092 | Cost: 0.8761
# Epoch: 008/010 | Batch 040/092 | Cost: 1.0150
# Epoch: 008/010 | Batch 044/092 | Cost: 0.6792
# Epoch: 008/010 | Batch 048/092 | Cost: 0.8273
# Epoch: 008/010 | Batch 052/092 | Cost: 0.7383
# Epoch: 008/010 | Batch 056/092 | Cost: 1.0435
# Epoch: 008/010 | Batch 060/092 | Cost: 0.9769
# Epoch: 008/010 | Batch 064/092 | Cost: 0.8331
# Epoch: 008/010 | Batch 068/092 | Cost: 0.9203
# Epoch: 008/010 | Batch 072/092 | Cost: 0.6898
# Epoch: 008/010 | Batch 076/092 | Cost: 0.8870
# Epoch: 008/010 | Batch 080/092 | Cost: 0.7024
# Epoch: 008/010 | Batch 084/092 | Cost: 0.8940
# Epoch: 008/010 | Batch 088/092 | Cost: 0.6140
# Epoch: 008/010 Train Acc.: 70.95% | Validation Acc.: 67.17%
# Time elapsed: 7.94 min
# Epoch: 009/010 | Batch 000/092 | Cost: 0.4710
# Epoch: 009/010 | Batch 004/092 | Cost: 0.8513
# Epoch: 009/010 | Batch 008/092 | Cost: 0.6648
# Epoch: 009/010 | Batch 012/092 | Cost: 0.7877
# Epoch: 009/010 | Batch 016/092 | Cost: 1.0373
# Epoch: 009/010 | Batch 020/092 | Cost: 0.8568
# Epoch: 009/010 | Batch 024/092 | Cost: 0.8990
# Epoch: 009/010 | Batch 028/092 | Cost: 0.7850
# Epoch: 009/010 | Batch 032/092 | Cost: 0.9176
# Epoch: 009/010 | Batch 036/092 | Cost: 0.5295
# Epoch: 009/010 | Batch 040/092 | Cost: 0.7011
# Epoch: 009/010 | Batch 044/092 | Cost: 0.8631
# Epoch: 009/010 | Batch 048/092 | Cost: 0.7816
# Epoch: 009/010 | Batch 052/092 | Cost: 0.5637
# Epoch: 009/010 | Batch 056/092 | Cost: 0.6180
# Epoch: 009/010 | Batch 060/092 | Cost: 0.6160
# Epoch: 009/010 | Batch 064/092 | Cost: 0.6022
# Epoch: 009/010 | Batch 068/092 | Cost: 1.0676
# Epoch: 009/010 | Batch 072/092 | Cost: 0.7732
# Epoch: 009/010 | Batch 076/092 | Cost: 0.5203
# Epoch: 009/010 | Batch 080/092 | Cost: 0.8545
# Epoch: 009/010 | Batch 084/092 | Cost: 1.1241
# Epoch: 009/010 | Batch 088/092 | Cost: 0.7510
# Epoch: 009/010 Train Acc.: 70.95% | Validation Acc.: 65.67%
# Time elapsed: 8.92 min
# Epoch: 010/010 | Batch 000/092 | Cost: 0.6415
# Epoch: 010/010 | Batch 004/092 | Cost: 0.7658
# Epoch: 010/010 | Batch 008/092 | Cost: 0.8115
# Epoch: 010/010 | Batch 012/092 | Cost: 1.0648
# Epoch: 010/010 | Batch 016/092 | Cost: 0.7731
# Epoch: 010/010 | Batch 020/092 | Cost: 1.0091
# Epoch: 010/010 | Batch 024/092 | Cost: 0.5650
# Epoch: 010/010 | Batch 028/092 | Cost: 0.6641
# Epoch: 010/010 | Batch 032/092 | Cost: 0.6968
# Epoch: 010/010 | Batch 036/092 | Cost: 0.8207
# Epoch: 010/010 | Batch 040/092 | Cost: 0.8634
# Epoch: 010/010 | Batch 044/092 | Cost: 0.9249
# Epoch: 010/010 | Batch 048/092 | Cost: 0.9510
# Epoch: 010/010 | Batch 052/092 | Cost: 0.6531
# Epoch: 010/010 | Batch 056/092 | Cost: 0.6062
# Epoch: 010/010 | Batch 060/092 | Cost: 0.7753
# Epoch: 010/010 | Batch 064/092 | Cost: 0.8859
# Epoch: 010/010 | Batch 068/092 | Cost: 0.7297
# Epoch: 010/010 | Batch 072/092 | Cost: 0.6380
# Epoch: 010/010 | Batch 076/092 | Cost: 0.8308
# Epoch: 010/010 | Batch 080/092 | Cost: 0.8659
# Epoch: 010/010 | Batch 084/092 | Cost: 0.7921
# Epoch: 010/010 | Batch 088/092 | Cost: 0.7815
# Epoch: 010/010 Train Acc.: 70.95% | Validation Acc.: 66.08%
# Time elapsed: 9.89 min
# Total Training Time: 9.89 min
